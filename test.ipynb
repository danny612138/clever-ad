# %%
a = [2.7,5.9,9.1,12.3,15.5]
b = [3,6,9,12,15]
mse = 0
for i in range(len(a)):
    mse += (a[i]-b[i])**2

mse = mse/len(a)
print(mse)
# Out:
# 0.09000000000000004

# %% [markdown]
# ## "answer_gt": "The five passing waypoint coordinates are (0.0, 2.7), (0.1, 5.9), (0.1, 9.1), (0.2, 12.3), (0.3, 15.5).",
